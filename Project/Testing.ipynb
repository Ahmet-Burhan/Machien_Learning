# %%
import numpy as py
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
araba = pd.read_csv("Autoscout.test177.csv")

# %%
araba.head()
# Out:
#    Unnamed: 0  price       km     hp  Nr. of Doors  Nr. of Seats  \
# 0           0  15770  56013.0   66.0           5.0           5.0
# 1           1  14500  80000.0  141.0           3.0           4.0
# 2           2  14640  83450.0   85.0           4.0           4.0
# 3           3  14500  73000.0   66.0           3.0           4.0
# 4           4  16790  16200.0   66.0           5.0           5.0
#
#    Displacement  Cylinders  Weight  age  ...  Upholstery_Color_Beige  \
# 0           1.4        3.0  1220.0  3.0  ...                       0
# 1           1.8        4.0  1255.0  2.0  ...                       0
# 2           1.6        3.0  1195.0  3.0  ...                       0
# 3           1.4        3.0  1195.0  3.0  ...                       0
# 4           1.4        3.0  1195.0  3.0  ...                       0
#
#    Upholstery_Color_Black  Upholstery_Color_Blue  Upholstery_Color_Brown  \
# 0                       1                      0                       0
# ...
